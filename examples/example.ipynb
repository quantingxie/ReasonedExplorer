# %%
import sys
sys.path.append('../')
from src.MCTS import MCTS
from src.exploration import Exploration
import openai

openai.api_key = "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"
MODEL = "gpt-4"

ETA = 0.1 # Scaling factor for exploration
GAMMA = 0.5 # N(S_t+1)^gamma
X = 4  # X nodes to abstract
K = 10  # How many iterations to run MCTS at each step
N = 5 # Action space and tree width
L = 5  # Tree length
r = 100 # radius of selection
fov = 86 # Field of View
rom = 70 # Range of motion


goal = "Find me a tennis racquet"
# Initialize MCTS
mcts_instance = MCTS(ETA, GAMMA, N, L, goal, MODEL)

# Initialize Exploration with the MCTS instance
explorer_instance = Exploration(mcts_instance, X, K, N, r, fov, rom, MODEL)

# Run the exploration process
explorer_instance.explore()
# Out:
# angle 226.13994585196343
# captured one image
# VLM set
# angle 240.13994585196343
# captured one image
# VLM set
# angle 254.13994585196343
# captured one image
# VLM set
# angle 268.13994585196343
# captured one image
# VLM set
# angle 282.13994585196343
# captured one image
# VLM set
# node expanded
# node expanded
# node expanded
# node expanded
# node expanded
# Given scene descriptions: ['You are looking at a park with various restaurants', 'You are looking at a park with various restaurants', 'You are looking at a park with various restaurants', 'You are looking at a park with various restaurants', 'You are looking at a park with various restaurants']
# Abstracted description: The scene is consistently set in a park that features a variety of restaurants.
# abstracted base nodes
# abstracted top nodes
# Node to rephrase: You are looking at a park with various restaurants
# Using global context: ['The scene is consistently set in a park that features a variety of restaurants.']
# Rephrased description: The scene is continually depicted in a park, which is characterized by an array of diverse restaurants.
# Node to rephrase: You are looking at a park with various restaurants
# Using global context: ['The scene is consistently set in a park that features a variety of restaurants.']
# Rephrased description: The scene is consistently set in a park, which is dotted with an array of diverse restaurants.
# Node to rephrase: You are looking at a park with various restaurants
# Using global context: ['The scene is consistently set in a park that features a variety of restaurants.']
# Rephrased description: The scene is consistently set in a park, which is dotted with an array of diverse restaurants.
# Node to rephrase: You are looking at a park with various restaurants
# Using global context: ['The scene is consistently set in a park that features a variety of restaurants.']
# Rephrased description: The scene is consistently set in a park, which is characterized by an array of diverse restaurants.
# Node to rephrase: You are looking at a park with various restaurants
# Using global context: ['The scene is consistently set in a park that features a variety of restaurants.']
# Rephrased description: The scene unfolds in a park, which is characterized by an assortment of diverse restaurants.
# expaned nodes rephrased
# Running MCTS
# Doing Selection
# Evaluating action for description 0
# Score: 1
# Q_value of action for description 0 = 0.1
# Evaluating action for description 1
# Score: 1
# Q_value of action for description 1 = 0.1
# Evaluating action for description 2
# Score: 1
# Q_value of action for description 2 = 0.1
# Evaluating action for description 3
# Score: 1
# Q_value of action for description 3 = 0.1
# Evaluating action for description 4
# Score: 1
# Q_value of action for description 4 = 0.1
# Doing Expansion
# Current scene observation: The scene is continually depicted in a park, which is characterized by an array of diverse restaurants.
# Extrapolated scene:
# On the far side of the plaza, a small farmers market is in full swing. Local farmers and artisans sell fresh produce, homemade jams, and handcrafted goods. The market is a riot of colors, with stalls piled high with ripe fruits, vibrant vegetables, and beautiful bouquets of flowers.
#
# Beyond the plaza, the park extends into a serene, tree-lined pathway leading to a picturesque lake. Here, a few more upscale restaurants with outdoor seating offer stunning views of the water. As the scene continues to unfold, it becomes clear that this park is not just a place for recreation, but a thriving gastronomic paradise, a testament to the city's rich culinary diversity.
# Score: 1
# Current scene observation: The scene is continually depicted in a park, which is characterized by an array of diverse restaurants.
# Extrapolated scene: Moving forward, the park evolves into a bustling food hub, a gastronomic paradise that attracts food enthusiasts from all corners of the city. The restaurants, each unique in their own right, have expanded their operations. Some have added outdoor seating areas, complete with string lights and cozy fire pits, where patrons can enjoy their meals under the open sky. Others have transformed into food trucks, offering a more casual and on-the-go dining experience.
#
# The park itself has grown lush and vibrant, with well-manicured lawns and blooming flower beds that add to the overall charm of the place. The paths winding through the park are now lined with food stalls, each offering a different cuisine, from Mexican to Italian, Indian to Japanese, and everything in between. The air is filled with the enticing aroma of a myriad of dishes being prepared, a sensory delight that draws in passersby.
#
# In the heart of the park, a large open space has been converted into a communal dining area. Long picnic tables and benches are scattered around, providing a place for people to sit, eat, and socialize. A stage has been set up at one end of the space, where live performances - from local bands to stand-up comedians - entertain the diners.
#
# On the outskirts of the park, a farmer's market has sprung up, offering fresh produce and artisanal goods. This not only provides the restaurants with high-quality, locally-sourced ingredients but also gives visitors the opportunity to take a piece of the park's culinary magic home with them.
#
# The park has truly transformed into a food lover's paradise, a place where one can indulge in a wide variety of cuisines while enjoying the beauty of nature and the warmth of community.
# Score: 1
# Current scene observation: The scene is continually depicted in a park, which is characterized by an array of diverse restaurants.
# Extrapolated scene: Moving forward, the park could evolve into a bustling food hub, where the diverse restaurants have expanded their operations. The once simple park is now a gastronomic paradise, filled with the enticing aromas of various cuisines from around the world.
#
# In the heart of the park, there is a large open-air food court, where the restaurants have set up additional stalls. Each stall is a miniaturized version of the main restaurant, offering a selection of their most popular dishes. The food court is a hive of activity, with chefs cooking in open kitchens, servers bustling about, and customers lining up to order their meals.
#
# The park's green spaces are now filled with picnic tables and benches, providing ample seating for visitors. There are also several food trucks parked along the perimeter of the park, offering everything from gourmet burgers to vegan smoothies.
#
# In one corner of the park, a stage has been set up for live performances. Local bands and musicians provide entertainment, adding to the lively atmosphere.
#
# The park's original walking paths have been maintained, but they now wind their way through the expanded food hub. Along these paths, there are small kiosks selling snacks and drinks, as well as artisanal food products like homemade jams, locally sourced honey, and handcrafted chocolates.
#
# At the far end of the park, a farmers' market has been established. Local farmers and producers sell fresh produce, dairy products, and baked goods. The market also features a few food stalls, where chefs prepare meals using the fresh ingredients available.
#
# The park has become a destination not just for food lovers, but also for those who enjoy the vibrant and lively atmosphere. It's a place where people come to enjoy good food, listen to live music, shop for local products, and simply enjoy the outdoors.
# Score: 1
# Doing simulation
# Current scene observation: v
# Extrapolated scene: It seems like you didn't provide a current scene observation. Could you please provide a detailed description of the scene you'd like me to extrapolate from?
# Score: 1
# Current scene observation: i
# Extrapolated scene: It seems like your scene description is incomplete. Could you please provide more details so I can help you better?
# Score: 3
# Current scene observation: n
# Extrapolated scene: It seems like there's a mistake in your request. Could you please provide the current scene observation for me to extrapolate from?
# Score: 1
# Current scene observation: g
# Extrapolated scene: Apologies, but the current scene observation provided is not sufficient to create a detailed scene description. Please provide a more detailed scene for extrapolation.
# Score: 3
# Current scene observation:
# Extrapolated scene: A small, rustic cabin sits nestled in the heart of a dense forest. The cabin is made of weathered wood, with a small chimney puffing out smoke. A narrow dirt path leads from the cabin's front door, winding its way through the trees. The forest is alive with the sounds of wildlife, and the air is filled with the scent of pine and damp earth. The sun is beginning to set, casting long shadows and bathing the forest in a warm, golden light.
#
# Potential future scene:
#
# As the dirt path continues deeper into the forest, it gradually widens and becomes more well-trodden. The trees begin to thin out, revealing a large, tranquil lake shimmering under the setting sun. The lake is surrounded by a grassy clearing, with wildflowers adding splashes of color to the green landscape. On the far side of the lake, there's a small wooden dock with a rowboat tied to it, gently bobbing in the water.
#
# A family of deer can be seen drinking from the lake, their soft brown coats glowing in the fading sunlight. Birds are returning to their nests in the trees around the lake, their songs filling the air. There's a small campfire area near the dock, with a few logs arranged around it for seating. The remains of a previous fire are still there, hinting at the possibility of human visitors.
#
# As the sun dips below the horizon, the forest and lake are bathed in a soft twilight, the stars beginning to twinkle in the clear sky above. The sounds of the forest at night begin to emerge, creating a peaceful symphony of nature. The cabin's light can still be seen in the distance, a warm beacon in the growing darkness.
# Score: 1
# Doing back_propagation
# Doing Selection
# Evaluating action for description 0
# Score: 1
# Q_value of action for description 0 = 1.85
# Evaluating action for description 1
# Score: 1
# Q_value of action for description 1 = 0.1
# Evaluating action for description 2
# Score: 1
# Q_value of action for description 2 = 0.1
# Evaluating action for description 3
# Score: 1
# Q_value of action for description 3 = 0.1
# Evaluating action for description 4
# Score: 1
# Q_value of action for description 4 = 0.1
# Doing Expansion
# Current scene observation: The scene is continually depicted in a park, which is characterized by an array of diverse restaurants.
# Extrapolated scene: Continuing forward, the scene evolves into a bustling food district, nestled within the heart of the park. The restaurants, each unique in their own right, are a blend of various global cuisines, from Italian trattorias to Japanese sushi bars, Mexican taquerias to French patisseries, and Indian curry houses to American diners. The air is filled with a tantalizing mix of aromas, from freshly baked bread to sizzling stir-fries, drawing in a steady stream of patrons.
#
# The park itself has been transformed into a lively hub of activity. The restaurants have expanded their seating areas onto the green spaces, with patrons enjoying their meals under the shade of towering trees and colorful umbrellas. Strung fairy lights twinkle above, casting a soft glow on the scene below.
#
# In the center of this food district, a large open space has been converted into a stage for live performances. Musicians, comedians, and artists take turns entertaining the crowd, adding to the vibrant atmosphere.
#
# To the side, local farmers and artisans have set up stalls, selling fresh produce, homemade jams, handcrafted jewelry, and other unique items. The stalls are a riot of colors, with the fresh fruits and vegetables, the vibrant textiles, and the shiny trinkets all competing for attention.
#
# Children run around in a dedicated play area, filled with swings, slides, and a merry-go-round. Laughter and squeals of delight echo through the park, blending with the hum of conversation and the clinking of cutlery.
#
# In the distance, a large pond glimmers under the setting sun, with paddle boats bobbing gently on its surface. A small ice cream stand is set up nearby, with a long line of people waiting for their turn.
#
# The scene is a perfect blend of gastronomy, entertainment, and nature, creating a lively and welcoming atmosphere that invites people to linger and enjoy. The park has truly become a melting pot of cultures, flavors, and experiences, reflecting the diversity and vibrancy of the city it resides in.
# Score: 1
# Current scene observation: The scene is continually depicted in a park, which is characterized by an array of diverse restaurants.
# Extrapolated scene:
# Street performers can be seen at various corners, their music and performances adding a lively rhythm to the city's heartbeat. People of all ages and walks of life can be seen walking down the sidewalks, some in a hurry, others leisurely enjoying the city's offerings.
#
# The scent of food wafts through the air, a mix of the various cuisines offered by the restaurants in the vicinity. From the spicy aroma of street food to the sweet scent of freshly baked goods, the city offers a sensory feast.
#
# In the distance, the city skyline is visible, with towering skyscrapers reaching towards the sky. The city lights begin to twinkle as evening approaches, reflecting off the glass buildings and creating a dazzling display.
#
# The city's public transportation system, including buses and trams, can be seen bustling along, providing an easy means for people to navigate through the city. The sound of traffic, chatter, and occasional laughter fills the air, creating a symphony of city life.
#
# The park's diverse restaurants have given way to a thriving urban district, offering a multitude of experiences and attractions for both locals and visitors. The scene is a testament to the city's dynamic nature, constantly evolving and growing while maintaining a connection to its roots.
# Score: 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 29
#      26 explorer_instance = Exploration(mcts_instance, X, K, N, r, fov, rom, MODEL)
#      28 # Run the exploration process
# ---> 29 explorer_instance.explore()
#
# File ~/Research/ReasonedExplorer/examples/../src/exploration.py:161, in Exploration.explore(self)
#     159 print("Running MCTS")
#     160 descriptions = [node.description for node in nodes]
# --> 161 self.mcts.run_mcts(self.k, descriptions)
#     163 for node in nodes:
#     164     self.Q_list[str(node)] = self.mcts.Q.get(str(node.description), 0)
#
# File ~/Research/ReasonedExplorer/examples/../src/MCTS.py:84, in MCTS.run_mcts(self, K, S_t1_list)
#      82 for k in range(K):
#      83     S_t1_star, depth = self.selection(S_t1_list, 1)
# ---> 84     S_t2_sample = self.expansion(S_t1_star)
#      85     pi_mean = self.simulation(S_t2_sample)
#      86     self.back_propagation(pi_mean, depth, S_t1_star)
#
# File ~/Research/ReasonedExplorer/examples/../src/MCTS.py:48, in MCTS.expansion(self, S_t1_star)
#      46 S_t2_pi_list = []
#      47 for _ in range(self.n):
# ---> 48     S_t2 = LLM_world_model(S_t1_star, model=self.model)
#      49     pi = LLM_evaluator(S_t2, self.goal, model=self.model)
#      50     S_t2_list.append(S_t2)
#
# File ~/Research/ReasonedExplorer/examples/../src/LLM_functions.py:43, in LLM_world_model(node, model)
#      37 prompt = f"""
#      38 You are an AI tasked with extrapolating from a given scene description. Based on the details provided in this scene, envision what this setting could evolve into if one were to continue forward. Your response should be a detailed scene description, focusing on potential elements that may logically appear ahead based on the current context.
#      39
#      40 Current scene observation: {node}
#      41 """
#      42 message=[{"role": "user", "content": prompt}]
# ---> 43 response = openai.ChatCompletion.create(
#      44     model="gpt-4",
#      45     messages = message,
#      46     temperature=0.2,
#      47     max_tokens=3000,
#      48     frequency_penalty=0.0
#      49 )
#      50 print(f"Current scene observation: {node}")
#      51 extrapolated_scene = response.choices[0].message['content'].strip()
#
# File ~/.local/lib/python3.10/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~/.local/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~/.local/lib/python3.10/site-packages/openai/api_requestor.py:288, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#     291         params=params,
#     292         supplied_headers=headers,
#     293         files=files,
#     294         stream=stream,
#     295         request_id=request_id,
#     296         request_timeout=request_timeout,
#     297     )
#     298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File ~/.local/lib/python3.10/site-packages/openai/api_requestor.py:596, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     594     _thread_context.session_create_time = time.time()
#     595 try:
# --> 596     result = _thread_context.session.request(
#     597         method,
#     598         abs_url,
#     599         headers=headers,
#     600         data=data,
#     601         files=files,
#     602         stream=stream,
#     603         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     604         proxies=_thread_context.session.proxies,
#     605     )
#     606 except requests.exceptions.Timeout as e:
#     607     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gmplot
#   Downloading gmplot-1.4.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.7/164.7 KB 3.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests in /home/droplab/.local/lib/python3.10/site-packages (from gmplot) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/droplab/.local/lib/python3.10/site-packages (from requests->gmplot) (1.26.16)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->gmplot) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/droplab/.local/lib/python3.10/site-packages (from requests->gmplot) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->gmplot) (2020.6.20)
# Installing collected packages: gmplot
# Successfully installed gmplot-1.4.1
